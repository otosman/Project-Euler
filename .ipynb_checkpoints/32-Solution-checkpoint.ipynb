# %%
'''
We shall say that an n-digit number is pandigital if it makes use of all the digits 1 to n exactly once; for example, the 5-digit number, 15234, is 1 through 5 pandigital.

The product 7254 is unusual, as the identity, 39 × 186 = 7254, containing multiplicand, multiplier, and product is 1 through 9 pandigital.

Find the sum of all products whose multiplicand/multiplier/product identity can be written as a 1 through 9 pandigital.

HINT: Some products can be obtained in more than one way so be sure to only include it once in your sum.
'''

# %%
def getFactors(n):
    l =[]
    for i in range(2,int(n/2)+1):
        if n % i == 0:
            l.append(i)
    return l
def isPandigital(num, size = 9):
    if ''.join(sorted(str(num))) == ''.join([str(x) for x in range(1,size+1)]):
        return True
    else: return False

def isDuplicated(num):
    x = False
    s = sorted(str(num))
    if s == set(s):
        x = True
    return x

def panFactors(num):
    tot = 0
    l = getFactors(num)
    s = str(num)
    for fact in l:
        if isDuplicated(s+str(fact)) == False:
            l2 = l[l.index(fact)+1:]
            for elem in l2:
                if isPandigital(s+str(fact)+str(elem)) and fact*elem == num:
                    tot = num
    return tot

# %%
tot = 0
for i in range (12,10001):
    if panFactors(i) != 0:
        tot += i
    
tot
# Out:
# 45228

# %%
#another smart solution I liked I did the first solution

from itertools import permutations

PermSet = set()

perms = [''.join(p) for p in permutations('123456789')]

#couldn't get the if statement to fit on one line.
#if up to and including the colon is supposed to be on one line.

for elem in perms:
    if int(elem[0])*int(elem[1:5]) == int(elem[5:9]) or int(elem[0:2])*int(elem[2:5]) == int(elem[5:9]):
        PermSet.add(int(elem[5:9]))

perms
# Out:
# ['123456789',
#  '123456798',
#  '123456879',
#  '123456897',
#  '123456978',
#  '123456987',
#  '123457689',
#  '123457698',
#  '123457869',
#  '123457896',
#  '123457968',
#  '123457986',
#  '123458679',
#  '123458697',
#  '123458769',
#  '123458796',
#  '123458967',
#  '123458976',
#  '123459678',
#  '123459687',
#  '123459768',
#  '123459786',
#  '123459867',
#  '123459876',
#  '123465789',
#  '123465798',
#  '123465879',
#  '123465897',
#  '123465978',
#  '123465987',
#  '123467589',
#  '123467598',
#  '123467859',
#  '123467895',
#  '123467958',
#  '123467985',
#  '123468579',
#  '123468597',
#  '123468759',
#  '123468795',
#  '123468957',
#  '123468975',
#  '123469578',
#  '123469587',
#  '123469758',
#  '123469785',
#  '123469857',
#  '123469875',
#  '123475689',
#  '123475698',
#  '123475869',
#  '123475896',
#  '123475968',
#  '123475986',
#  '123476589',
#  '123476598',
#  '123476859',
#  '123476895',
#  '123476958',
#  '123476985',
#  '123478569',
#  '123478596',
# ...
